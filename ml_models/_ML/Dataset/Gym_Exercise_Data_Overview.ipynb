# %% [markdown]
# # Gym Member Exercise Dataset
# Analysing fitness patterns and trends across diverse gym experience levels

# %% [markdown]
# This dataset provides a detailed overview of gym members' exercise routines, physical attributes, and fitness metrics. It contains 973 samples of gym data, including key performance indicators such as heart rate, calories burned, and workout duration. Each entry also includes demographic data and experience levels, allowing for comprehensive analysis of fitness patterns, athlete progression, and health trends.
#
# Key Features:
#
# - Age: Age of the gym member.
# - Gender: Gender of the gym member (Male or Female).
# - Weight (kg): Member’s weight in kilograms.
# - Height (m): Member’s height in meters.
# - Max_BPM: Maximum heart rate (beats per minute) during workout sessions.
# - Avg_BPM: Average heart rate during workout sessions.
# - Resting_BPM: Heart rate at rest before workout.
# - Session_Duration (hours): Duration of each workout session in hours.
# - Calories_Burned: Total calories burned during each session.
# - Workout_Type: Type of workout performed (e.g., Cardio, Strength, Yoga, HIIT).
# - Fat_Percentage: Body fat percentage of the member.
# - Water_Intake (liters): Daily water intake during workouts.
# - Workout_Frequency (days/week): Number of workout sessions per week.
# - Experience_Level: Level of experience, from beginner (1) to expert (3).
# - BMI: Body Mass Index, calculated from height and weight.
#
#
# This dataset is ideal for data scientists, health researchers, and fitness enthusiasts interested in studying exercise habits, modeling fitness progression, or analyzing the relationship between demographic and physiological data. With a wide range of variables, it offers insights into how different factors affect workout intensity, endurance, and overall health.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading the dataset

df = pd.read_csv("C:/Users/nikau/OneDrive/Desktop/My Work/DataSets/gym_members_exercise_tracking.csv")

# %% [markdown]
# ### EDA (Exploratory Data Analysis)

# %%
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df.shape
# Out:
# (973, 15)

# %%
df.tail()
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 968                      1.57           1364.0     Strength            10.0
# 969                      1.38           1260.0     Strength            25.0
# 970                      1.72            929.0       Cardio            18.8
# 971                      1.10            883.0         HIIT            28.2
# 972                      0.75            542.0     Strength            28.8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            973 non-null    int64
#  1   Gender                         973 non-null    object
#  2   Weight (kg)                    973 non-null    float64
#  3   Height (m)                     973 non-null    float64
#  4   Max_BPM                        973 non-null    int64
#  5   Avg_BPM                        973 non-null    int64
#  6   Resting_BPM                    973 non-null    int64
#  7   Session_Duration (hours)       973 non-null    float64
#  8   Calories_Burned                973 non-null    float64
#  9   Workout_Type                   973 non-null    object
#  10  Fat_Percentage                 973 non-null    float64
#  11  Water_Intake (liters)          973 non-null    float64
# ...

# %%
df.describe()
# Out:
#               Age  Weight (kg)  Height (m)     Max_BPM     Avg_BPM  \
# count  973.000000   973.000000   973.00000  973.000000  973.000000
# mean    38.683453    73.854676     1.72258  179.883864  143.766701
# std     12.180928    21.207500     0.12772   11.525686   14.345101
# min     18.000000    40.000000     1.50000  160.000000  120.000000
# 25%     28.000000    58.100000     1.62000  170.000000  131.000000
# 50%     40.000000    70.000000     1.71000  180.000000  143.000000
# 75%     49.000000    86.000000     1.80000  190.000000  156.000000
# max     59.000000   129.900000     2.00000  199.000000  169.000000
#
#        Resting_BPM  Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count   973.000000                973.000000       973.000000      973.000000
# mean     62.223022                  1.256423       905.422405       24.976773
# std       7.327060                  0.343033       272.641516        6.259419
# ...

# %% [markdown]
# Summary Statistics
#
# - Age: ranges from 18 to 59 with an average of 38
# - Weight(kg) ranges from 40 to 129.9 with and average of 73.8
# - Height(m) ranges from 1.5 to 2.0 with an average of 1.72
# - Max BPM ranges from 199 to 160 with an average of 143.76
# - Session Duration(hours) ranges from 2 to 0.5 with an average of 1.2
# - Calories Burned ranges 1783 to 303 with an average 903
# - Fat Percentage ranges from 35 to 10 with an average of 24.9
# - Water Intake(liters) ranges from 3.7 to 1.5 with an average of 2.6
# - Workout Frequency(days/week) ranges from 5 to 2 with an average of 3.3
# - Experience Level ranges from 3 to 1 with an average of 1.8
# - BMI ranges from 49.8 to 12.3 with an average of 24.9

# %%
df.isnull().sum()
# Out:
# Age                              0
# Gender                           0
# Weight (kg)                      0
# Height (m)                       0
# Max_BPM                          0
# Avg_BPM                          0
# Resting_BPM                      0
# Session_Duration (hours)         0
# Calories_Burned                  0
# Workout_Type                     0
# Fat_Percentage                   0
# Water_Intake (liters)            0
# Workout_Frequency (days/week)    0
# Experience_Level                 0
# BMI                              0
# dtype: int64

# %% [markdown]
# there are no missing values prensent in this dataset

# %% [markdown]
# Categorical Values

# %%
df['Gender'].value_counts()
# Out:
# Male      511
# Female    462
# Name: Gender, dtype: int64

# %%
df['Workout_Type'].value_counts()
# Out:
# Strength    258
# Cardio      255
# Yoga        239
# HIIT        221
# Name: Workout_Type, dtype: int64

# %%
# Setting up the plot size and style
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Creating the plot
sns.countplot(data=df, x="Workout_Type", hue='Gender', palette='Set1' )

# Setting titles for the axes
plt.title('Workout Types by Gender', fontsize = 16)
plt.xlabel('Workout Types', fontsize = 12)
plt.ylabel('Count', fontsize = 12)
plt.legend(title = 'Gender')

# Display the plot
plt.show()

# %%
# Setting up the plot size and style
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Creating the Bar Chart
sns.barplot(data = df, x = "Workout_Type", y = "Calories_Burned", hue = "Gender", palette = "Set3")

# Adding title and labels
plt.title('Calories Burned by Workout Type', fontsize=16)
plt.xlabel('Workout Type', fontsize=12)
plt.ylabel('Amount of Calories Burned', fontsize=12)

# Display the graph
plt.show()

# %%
# Setting up the plot size and style
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Creating the Bar Chart
sns.barplot(data = df, x = "Workout_Type", y = "Water_Intake (liters)", hue = "Gender", palette = "ocean")

# Adding title and labels
plt.title('Water Intake by Workout Type', fontsize=16)
plt.xlabel('Workout Type', fontsize=12)
plt.ylabel('Amount of Water Consumed', fontsize=12)

# Display the graph
plt.show()

# %%
# Setting up the plot size and style
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Creating the plot
sns.countplot(data=df, x='Experience_Level', hue='Gender', palette = 'Set2')

# Adding title and labels
plt.title('Level of Experience Amongst Gym Users', fontsize=16)
plt.xlabel('Experience', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Display the plot
plt.show()

# %%
# Setting up the plot size and style
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Creating the Count plot
sns.countplot(data = df, x = 'Workout_Frequency (days/week)', hue = 'Gender', palette = 'coolwarm')

# Adding title and labels
plt.title('Count Plot of Workout Frequency', fontsize=16)
plt.xlabel('Workout Frequency (Days per Week)', fontsize=12)
plt.ylabel('Density', fontsize=12)

# Display the plot
plt.show()

# %%
# Setting up the plot size and style
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Creating the plot
sns.distplot(df['Age'], color='red')

# Adding title and labels
plt.title('Distribution of Age Amongst Gym Users', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Display the plot
plt.show()
# Out:
# C:\Users\nikau\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Setting up the plot size and style
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Creating the plot
sns.distplot(df['Weight (kg)'], color='blue')

# Adding title and labels
plt.title('Distribution of Weight Amongst Gym Users', fontsize=16)
plt.xlabel('Weight (kg)', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Display the plot
plt.show()
# Out:
# C:\Users\nikau\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Setting up the plot size and style
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Creating the plot
sns.distplot(df['Height (m)'], color='purple')

# Adding title and labels
plt.title('Distribution of Height Amongst Gym Users', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Display the plot
plt.show()
# Out:
# C:\Users\nikau\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Setting up the plot size
plt.figure(figsize=(10, 6))

# Creating the KDE plot
sns.kdeplot(data=df['Fat_Percentage'], shade=True, color='green')

# Adding title and labels
plt.title('Density Plot of Fat Percentage', fontsize=16)
plt.xlabel('Fat Percentage', fontsize=12)
plt.ylabel('Density', fontsize=12)

# Display the plot
plt.show()

# %%
# Setting up the plot size
plt.figure(figsize=(10, 6))

# Creating the Scatter plot
sns.scatterplot(data = df,  x = "Weight (kg)", y = "BMI", hue = "Gender", palette = "YlOrRd_r")

# Adding title and labels
plt.title('Scatter Plot of Fat Percentage by Gender', fontsize=16)
plt.xlabel('Fat Percentage', fontsize=12)
plt.ylabel('Density', fontsize=12)

# Display the plot
plt.show()

# %%
# Setting up the plot size
plt.figure(figsize=(10, 6))

# Creating the Scatter plot
sns.scatterplot(data = df,  x = "Weight (kg)", y = "BMI", hue = "Experience_Level", palette = "YlOrRd_r")

# Adding title and labels
plt.title('Scatter Plot of Fat Percentage by Experience', fontsize=16)
plt.xlabel('Fat Percentage', fontsize=12)
plt.ylabel('Density', fontsize=12)

# Display the plot
plt.show()

# %%
# Setting up the plot size and style
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Creating the Scatter plot
sns.scatterplot(data = df, x = 'Session_Duration (hours)', y = 'Calories_Burned', hue = 'Gender', palette = "crest_r")

# Adding title and labels
plt.title('Calories Burned vs Workout Duration by Gender', fontsize=16)
plt.xlabel('Session Duration (hours)', fontsize=12)
plt.ylabel('Calories Burned', fontsize=12)

# Display the plot
plt.show()

# %%
# Setting up the plot size and style
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Creating the Scatter plot
sns.scatterplot(data = df, x = 'Session_Duration (hours)', y = 'Calories_Burned', hue = 'Experience_Level', palette = "spring")

# Adding title and labels
plt.title('Calories Burned vs Workout Duration by Experience', fontsize=16)
plt.xlabel('Session Duration (hours)', fontsize=12)
plt.ylabel('Calories Burned', fontsize=12)

# Display the plot
plt.show()

# %%
df.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
# Setting up the plot size
plt.figure(figsize=(10, 6))

# Creating the Box plot
sns.boxplot(data = df, x = "Gender", y = "Session_Duration (hours)", palette = "afmhot")

# Adding title and labels
plt.title('Comparison of Session Duration by Gender', fontsize=16)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Session Duration (hours)', fontsize=12)

# Display the plot
plt.show()

# %%
# Setting up the plot size
plt.figure(figsize=(10, 6))

# Creating the Box plot
sns.boxplot(data = df, x = "Experience_Level", y = "Session_Duration (hours)", palette = "coolwarm")

# Adding title and labels
plt.title('Comparison of Session Duration by Experience Level', fontsize=16)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Session Duration (hours)', fontsize=12)

# Display the plot
plt.show()

# %%
df.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
# Setting up the plot size
plt.figure(figsize=(10, 6))

# Creating the Box plot
sns.boxplot(data = df, x = "Workout_Type", y = "BMI", palette="Set3")

# Adding title and labels
plt.title('Comparison of Session Duration by Workout Type', fontsize=16)
plt.xlabel('Workout Type', fontsize=12)
plt.ylabel('BMI', fontsize=12)

# Display the plot
plt.show()

# %%
# Setting up the plot size
plt.figure(figsize=(10, 6))

# Creating the Scatterplot
sns.scatterplot(data = df, x = "Age", y = "BMI", hue = "Gender", palette='Set2')

# Adding title and labels
plt.title('Age vs BMI', fontsize=16)
plt.xlabel('BMI', fontsize=12)
plt.ylabel('Age', fontsize=12)

# Display the plot
plt.show()

# %%
# Creating a new correlation data frame
df_num = df[["Weight (kg)", "Height (m)", "Calories_Burned", "BMI", "Session_Duration (hours)", "Gender"]]

# Setting up the plot size
plt.figure(figsize=(10, 6))

# Creting the Pairplot
sns.pairplot(df_num, hue = "Gender", palette = "Set1")

# Display the plot
plt.show()

# %%
# Setting up the plot size
plt.figure(figsize=(15, 10))

# Creating the Heatmap
sns.heatmap(df.corr(), annot = True)
# Out:
# C:\Users\nikau\AppData\Local\Temp/ipykernel_28184/658627996.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)
# <AxesSubplot:>

# %% [markdown]
# ### Splitting the Data Set

# %%
# Seperating the X and Y variables

X = df.drop("BMI", axis=1)
Y = df["BMI"] # Target Variable

# One-hot encoding for Gender (since it's categorical)
X = pd.get_dummies(X, columns=["Gender", "Workout_Type"], drop_first=True)


print('shape of x:', X.shape)
print('shape of y:', Y.shape)
# Out:
# shape of x: (973, 16)
# shape of y: (973,)

# %%
from sklearn.model_selection import train_test_split

# fitting the variables
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size= 0.2, random_state = 10,)

print('shape of X_train :',x_train.shape)
print('shape of y_train :',y_train.shape)
print('shape of X_test :',x_test.shape)
print('shape of y_test :',y_test.shape)
# Out:
# shape of X_train : (778, 16)
# shape of y_train : (778,)
# shape of X_test : (195, 16)
# shape of y_test : (195,)

# %% [markdown]
# ### First Model: Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Fitting the Decion Tree Regressor Model
DTR = DecisionTreeRegressor()
model_parameters = {
    'criterion' : ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
    'splitter' : ['best', 'random'],
    'max_depth' : [2, 4, 8, 16, 32],
    'min_samples_split' : [2, 4, 8, 10, 16]
}

# Cross Validation

Grid_Model = GridSearchCV(DTR, model_parameters, cv = 5, scoring='neg_mean_squared_error')
Grid_Model.fit(x_train, y_train)

print("The best score is", Grid_Model.best_score_)
print("The best parameters are ", Grid_Model.best_params_)

# Making predictions on the test set using the best model
y_pred = Grid_Model.best_estimator_.predict(x_test)

# Evaluating the model using R-squared and Mean Squared Error
mse_tree = mean_squared_error(y_test, y_pred)
r2_tree = r2_score(y_test, y_pred)

print("Mean Squared Error on test data:", mse_tree)
print("R-squared on test data:", r2_tree)
# Out:
# The best score is -1.293848779983457
# The best parameters are  {'criterion': 'absolute_error', 'max_depth': 16, 'min_samples_split': 2, 'splitter': 'best'}
# Mean Squared Error on test data: 1.1002594871794877
# R-squared on test data: 0.9767128580903804

# %% [markdown]
# ###  Second Model: Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
# Creating the Linear Regression Model
Linear_Model = LinearRegression()

# Fit the model on the training data
Linear_Model.fit(x_train, y_train) # Trains the linear regression model on the training data.

# Make predictions on the test data set
y_pred = Linear_Model.predict(x_test) # Generates predictions for the test data.

# Evaluate the model performance
mse_linear = mean_squared_error(y_test, y_pred)
r2_linear = r2_score(y_test, y_pred)

# Print the evaluation metrics
print("Mean Squared Error (MSE)", mse_linear) # Measures the average squared difference between predicted and actual values (the lower, the better)
print("R-squared (R²):", r2_linear) # Indicates how well the model explains the variance in the target variable (closer to 1 is better)
# Out:
# Mean Squared Error (MSE) 0.7074747985332954
# R-squared (R²): 0.9850261995257518

# %% [markdown]
# ### Third Model: Ridge Regression

# %%
from sklearn.linear_model import Ridge, Lasso

# Creating the Ridge Regression Model
Ridge_Model = Ridge(alpha = 1.0)

# Fit the model on the training data
Ridge_Model.fit(x_train, y_train)

# Make predictions on the test data set
y_pred_ridge = Ridge_Model.predict(x_test)

# Evaluate the model performance
mse_ridge = mean_squared_error(y_test, y_pred_ridge)
r2_ridge = r2_score(y_test, y_pred_ridge)

# Print the evaluation metrics
print("Mean Squared Error (MSE)", mse_ridge) # Measures the average squared difference between predicted and actual values (the lower, the better)
print("R-squared (R²):", r2_ridge) # Indicates how well the model explains the variance in the target variable (closer to 1 is better)
# Out:
# Mean Squared Error (MSE) 0.8841802194689616
# R-squared (R²): 0.9812862052230654

# %% [markdown]
# ### Fourth Model : Lasso Regression

# %%
# Creating the Lasso Regression Model
Lasso_Model = Lasso(alpha = 0.1)

# Fit the model on the training data
Lasso_Model.fit(x_train, y_train)

# Make predictions on the test data set
y_pred_lasso = Lasso_Model.predict(x_test)

# Evaluate the model performance
mse_lasso = mean_squared_error(y_test, y_pred_lasso)
r2_lasso = r2_score(y_test, y_pred_lasso)

# Print the evaluation metrics
print("Mean Squared Error (MSE)", mse_lasso) # Measures the average squared difference between predicted and actual values (the lower, the better)
print("R-squared (R²):", r2_lasso) # Indicates how well the model explains the variance in the target variable (closer to 1 is better)
# Out:
# Mean Squared Error (MSE) 1.6677707272967854
# R-squared (R²): 0.9647014053940769

# %% [markdown]
# ### Results

# %%
# Adding the results to the existing ones
models = ['Ridge Regression', 'Lasso Regression', 'Linear Regression', 'Decision Tree Regressor']
mse_values = [mse_ridge, mse_lasso, mse_linear, mse_tree]
r2_values = [r2_ridge, r2_lasso, r2_linear, r2_tree]

# Plotting MSE and R-Squared in separate bar plots
plt.figure(figsize=(14, 6))

# MSE Bar Plot
plt.subplot(1, 2, 1)
plt.bar(models, mse_values, color=['skyblue', 'lightgreen', 'lightcoral', 'lightblue'])
plt.title('Mean Squared Error (MSE)')
plt.ylabel('MSE')
plt.xticks(rotation=45)

# R-Squared Bar Plot
plt.subplot(1, 2, 2)
plt.bar(models, r2_values, color=['skyblue', 'lightgreen', 'lightcoral', 'lightblue'])
plt.title('R-Squared (R²)')
plt.ylabel('R²')
plt.xticks(rotation=45)

# Adjust layout and display the plots
plt.tight_layout()
plt.show()
